# %%
valores = []
type(valores)
valores = [0,1,2,3]
valores
5 in valores
3 in valores
min(valores)
max(valores)

valores.append(7)
valores
valores.remove(1)
valores
print(len(valores))
print(valores[3])
# Out:
# 4
# 7
