# %%
def jogar():
    print("*********************************")
    print("***Bem vindo ao jogo da Forca!***")
    print("*********************************")

    palavra_secreta = "banana"
    letras_acertadas = ["_", "_", "_", "_", "_", "_"]
    acertos = len(palavra_secreta)
    finalizar = 'N'

    enforcou = False
    acertou = False

    print(letras_acertadas)

    while(not enforcou and not acertou and finalizar.upper() =='N'):

        chute = input("Qual letra?")
        chute = chute.strip()

        index = 0
        for letra in palavra_secreta:
            if(chute.upper() == letra.upper()):
                letras_acertadas[index] = letra
                acertos = acertos-1;
            index = index + 1

        print(letras_acertadas)
        if(acertos==0):
          print('Ganhou')
          finalizar = input("Deseja finalizar S/N -> ")
          letras_acertadas = ["_", "_", "_", "_", "_", "_"]
          acertos = len(palavra_secreta)

          if (finalizar.upper=='S'):
              print("Fim do jogo")
        
              

   

if(__name__ == "__main__"):
    jogar()
# Out:
# *********************************
# ***Bem vindo ao jogo da Forca!***
# *********************************
# ['_', '_', '_', '_', '_', '_']
# Qual letra?a
# ['_', 'a', '_', 'a', '_', 'a']
# Qual letra?n
# ['_', 'a', 'n', 'a', 'n', 'a']
# Qual letra?b
# ['b', 'a', 'n', 'a', 'n', 'a']
# Ganhou
# Deseja finalizar S/N -> n
# Qual letra?a
# ['_', 'a', '_', 'a', '_', 'a']
# Qual letra?b
# ['b', 'a', '_', 'a', '_', 'a']
# Qual letra?n
# ['b', 'a', 'n', 'a', 'n', 'a']
# Ganhou
# Deseja finalizar S/N -> s
