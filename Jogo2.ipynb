# %%
import random

print("|********************|")
print("|Jogo de Adivinhação |")
print("|********************|")

numero_secreto = round(random.randrange(0,101))
print("numero_secreto {}".format(numero_secreto))
rodada = 1
finalizar = "N"

print("Qual nível de dificuldade?")
print("1 Fácil | 2 Médio | 3 Difícil")
nivel = int(input("Defina o nível -> "))


if (nivel==1):
  total_de_tentativas = 5
elif(nivel==2):
  total_de_tentativas = 3
else:
    total_de_tentativas = 1

while (finalizar!="S" ):
  print("Tentativa {} de {}".format(rodada,total_de_tentativas))
  chute_str = input("Digite um valor -> ")
  
  print("Você digitou ",chute_str)
  chute = int(chute_str)

  if (chute < 1 or chute >100):
    print("Digite um valor entre 1 e 100")
    continue

  acertou = numero_secreto==chute
  maior = chute > numero_secreto
  menor = chute < numero_secreto

  if(acertou):
    print("Você acertou")    
  else:
    if(maior):
      print("Você errou! Chute maior que número secreto")
    elif(menor):
      print("Você errou! Chute menor que número secreto")

    
      finalizar = input("Deseja finalizar S/N -> ");
      if (finalizar=="S" or finalizar=="s"):
        print("#Fim do Jogo#")
        break
      else:
        rodada = rodada + 1
# Out:
# |********************|
# |Jogo de Adivinhação |
# |********************|
# numero_secreto 27
# Qual nível de dificuldade?
# 1 Fácil | 2 Médio | 3 Difícil
# Defina o nível -> 2
# Tentativa 1 de 10
# Digite um valor -> 50
# Você digitou  50
# Você errou! Chute maior que número secreto
# Tentativa 1 de 10
# Digite um valor -> 2
# Você digitou  2
# Você errou! Chute menor que número secreto
# Deseja finalizar S/N -> s
# #Fim do Jogo#
