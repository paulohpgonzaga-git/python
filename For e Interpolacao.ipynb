# %%
x = 5



print("Teste de Interpolação {0} {1}".format("Python","é top"))

print("R$ {:6.2f}".format(1000.12))

print("R$ {:09.2f}".format(100.12))


for x in range(0,10):
  
  print("impressão {}".format(x))

print("----------------------------------------\n")
for x in range(0,10,3):
  print(x)
# Out:
# Teste de Interpolação Python é top
# R$ 1000.12
# R$ 000100.12
# impressão 0
# impressão 1
# impressão 2
# impressão 3
# impressão 4
# impressão 5
# impressão 6
# impressão 7
# impressão 8
# impressão 9
# ----------------------------------------
#
# 0
# 3
# 6
# 9
